# %%
n = 42

# %%
42 = n
# Out:
#   Cell In[2], line 1
#     42 = n
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x = y = 1

# %%
x = 5;

# %%
x = 3
y = 4
print(x * y)
# Out:
# 12

# %%
import math

r = 5
volume = 4/3 * math.pi * r**3
volume
# Out:
# 523.5987755982989

# %%
cover_price = 24.95
discount = 0.4
copies = 60

book_price = cover_price * (1 - discount)
books_total = book_price * copies

shipping = 3 + 0.75 * (copies - 1)

total_cost = books_total + shipping
total_cost
# Out:
# 945.4499999999999

# %%
easy = 8 + 15/60
tempo = 7 + 12/60

total_minutes = easy + 3*tempo + easy
total_minutes
# Out:
# 38.1

# %%
start_minutes = 6*60 + 52
end_minutes = start_minutes + total_minutes

hours = int(end_minutes // 60)
minutes = int(end_minutes % 60)

hours, minutes
# Out:
# (7, 30)
